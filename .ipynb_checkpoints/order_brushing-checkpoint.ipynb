# %%
b = dt.timedelta(hours=1)

# %%
dummie[1]
# Out:
# Timestamp('2019-12-27 11:54:20')

# %%
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('order_brush_order.csv',parse_dates=['event_time'])

# %%
data.head()
# Out:
#           orderid     shopid     userid          event_time
# 0  31076582227611   93950878   30530270 2019-12-27 00:23:03
# 1  31118059853484  156423439   46057927 2019-12-27 11:54:20
# 2  31123355095755  173699291   67341739 2019-12-27 13:22:35
# 3  31122059872723   63674025  149380322 2019-12-27 13:01:00
# 4  31117075665123  127249066  149493217 2019-12-27 11:37:55

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222750 entries, 0 to 222749
# Data columns (total 4 columns):
# orderid       222750 non-null int64
# shopid        222750 non-null int64
# userid        222750 non-null int64
# event_time    222750 non-null datetime64[ns]
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 6.8 MB

# %%
sns.heatmap(data.isna())

# %%
data = data.drop(labels = 'orderid' , axis = 1)

# %%
#identify shop as unique number
shop_unique = data['shopid'].unique()
user_unique = data['userid'].unique()

# %%
shopid = []
duration = []
count = []
for i in shop_unique:
    if i not in shopid:
        dummie_df = data[data['shopid'] == i]
        dummie_df.reset_index()
        for j in range(len(dummie_df)):
            index = j+1
            if index > len(dummie_df):
                index = j
            if dummie_df['event_time'][index] - dummie_df['event_time'][j] < dt.timedelta(hours=1):
                count.append(dummie_df['userid'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-144-662489760009> in <module>
#      10             if index > len(dummie_df):
#      11                 index = j
# ---> 12             if dummie_df['event_time'][index] - dummie_df['event_time'][j] < dt.timedelta(hours=1):
#      13                 count.append(dummie_df['userid'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4373         try:
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#    4377             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1

# %%
# Out:
#            shopid    userid          event_time
# 222725  147118226  47283981 2019-12-28 03:16:09

# %%
bb = data[data['shopid'] == 93950878]

# %%
a
# Out:
# Timedelta('-1 days +12:28:43')

# %%
a < dt.timedelta(hours=1)
# Out:
# True

# %%
a
# Out:
# Timedelta('-1 days +12:28:43')

# %%
data['orderid'].nunique()
# Out:
# 222750

# %%
a = data[data['shopid'] == 93950878]

# %%
if a['event_time'][0] - a['event_time'][4130] > dt.timedelta(hours=1):
    print('yes')
else:
    print('no')
# Out:
# no

# %%
bb.reset_index()
# Out:
#       index    shopid     userid          event_time
# 0         0  93950878   30530270 2019-12-27 00:23:03
# 1      4130  93950878  200055785 2019-12-31 01:08:23
# 2      8774  93950878  103695259 2019-12-29 22:17:13
# 3      9646  93950878   16996136 2019-12-30 10:07:07
# 4     18802  93950878  133955528 2019-12-27 20:42:49
# 5     22176  93950878   39501363 2019-12-30 23:50:02
# 6     22988  93950878    8836682 2019-12-30 13:17:18
# 7     24447  93950878   11131542 2019-12-30 20:21:25
# 8     27864  93950878  112278302 2019-12-27 20:30:56
# 9     28275  93950878  153538082 2019-12-30 13:22:05
# 10    32147  93950878   56257484 2019-12-31 00:17:43
# 11    33010  93950878  115726083 2019-12-28 23:35:52
# 12    33691  93950878  103547482 2019-12-30 21:09:32
# 13    34891  93950878  177433143 2019-12-29 06:54:31
# 14    35940  93950878  203330580 2019-12-28 14:57:29
# 15    39171  93950878   89603889 2019-12-27 09:25:48
# 16    41787  93950878  211578329 2019-12-30 14:08:02
# 17    43728  93950878  200011199 2019-12-27 13:50:42
# 18    45730  93950878   64863054 2019-12-27 20:07:42
# 19    47383  93950878   68936845 2019-12-29 15:35:25

# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-164-da3e4f5d1a10> in <module>
#       4     if time > len(b):
#       5         time = len(b)
# ----> 6     if b['event_time'][i+1] - b['event_time'][i] > dt.timedelta(hours=1):
#       7         print('y')
#       8     else:
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4373         try:
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#    4377             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1

# %%
b = a

# %%
b.reindex(range(len(b)))
# Out:
#           orderid      shopid      userid          event_time
# 0    3.107658e+13  93950878.0  30530270.0 2019-12-27 00:23:03
# 1             NaN         NaN         NaN                 NaT
# 2             NaN         NaN         NaN                 NaT
# 3             NaN         NaN         NaN                 NaT
# 4             NaN         NaN         NaN                 NaT
# 5             NaN         NaN         NaN                 NaT
# 6             NaN         NaN         NaN                 NaT
# 7             NaN         NaN         NaN                 NaT
# 8             NaN         NaN         NaN                 NaT
# 9             NaN         NaN         NaN                 NaT
# 10            NaN         NaN         NaN                 NaT
# 11            NaN         NaN         NaN                 NaT
# 12            NaN         NaN         NaN                 NaT
# 13            NaN         NaN         NaN                 NaT
# 14            NaN         NaN         NaN                 NaT
# 15            NaN         NaN         NaN                 NaT
# 16            NaN         NaN         NaN                 NaT
# 17            NaN         NaN         NaN                 NaT
# 18            NaN         NaN         NaN                 NaT
# 19            NaN         NaN         NaN                 NaT
# 20            NaN         NaN         NaN                 NaT
# 21            NaN         NaN         NaN                 NaT
# 22            NaN         NaN         NaN                 NaT
# 23            NaN         NaN         NaN                 NaT
# 24            NaN         NaN         NaN                 NaT
# 25            NaN         NaN         NaN                 NaT
# 26            NaN         NaN         NaN                 NaT
# 27            NaN         NaN         NaN                 NaT
# 28            NaN         NaN         NaN                 NaT
# 29            NaN         NaN         NaN                 NaT
# ..            ...         ...         ...                 ...
# 94            NaN         NaN         NaN                 NaT
# 95            NaN         NaN         NaN                 NaT
# 96            NaN         NaN         NaN                 NaT
# 97            NaN         NaN         NaN                 NaT
# 98            NaN         NaN         NaN                 NaT
# 99            NaN         NaN         NaN                 NaT
# 100           NaN         NaN         NaN                 NaT
# 101           NaN         NaN         NaN                 NaT
# 102           NaN         NaN         NaN                 NaT
# 103           NaN         NaN         NaN                 NaT
# 104           NaN         NaN         NaN                 NaT
# 105           NaN         NaN         NaN                 NaT
# 106           NaN         NaN         NaN                 NaT
# 107           NaN         NaN         NaN                 NaT
# 108           NaN         NaN         NaN                 NaT
# 109           NaN         NaN         NaN                 NaT
# 110           NaN         NaN         NaN                 NaT
# 111           NaN         NaN         NaN                 NaT
# 112           NaN         NaN         NaN                 NaT
# 113           NaN         NaN         NaN                 NaT
# 114           NaN         NaN         NaN                 NaT
# 115           NaN         NaN         NaN                 NaT
# 116           NaN         NaN         NaN                 NaT
# 117           NaN         NaN         NaN                 NaT
# 118           NaN         NaN         NaN                 NaT
# 119           NaN         NaN         NaN                 NaT
# 120           NaN         NaN         NaN                 NaT
# 121           NaN         NaN         NaN                 NaT
# 122           NaN         NaN         NaN                 NaT
# 123           NaN         NaN         NaN                 NaT
#
# [124 rows x 4 columns]
